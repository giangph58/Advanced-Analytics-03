# %%
import glob
import pandas as pd
from src.utils import map_category
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from datasets import load_from_disk

# %%
all_stream_data = load_from_disk("data/processed/all_stream_data")

# %%
all_stream_data.set_format(type="pandas")
train_df = all_stream_data["train"][:]
valid_df = all_stream_data["validation"][:]

# %%
X_train, y_train = train_df["text"], train_df["label"]
X_valid, y_valid = valid_df["text"], valid_df["label"]
labels = all_stream_data["train"].features["label"].names

# %%
vectorizer = TfidfVectorizer(
        sublinear_tf=True, max_df=0.5, min_df=5, stop_words="english"
    )
X_train = vectorizer.fit_transform(X_train)
X_valid = vectorizer.transform(X_valid)

# %%
from sklearn.metrics import balanced_accuracy_score, f1_score
from sklearn.utils.extmath import density
from time import time

def benchmark(clf, custom_name=False):
    print("_" * 80)
    print("Training: ")
    print(clf)
   
    t0 = time()
    clf.fit(X_train, y_train)
    train_time = time() - t0
    print(f"train time: {train_time:.3}s")

    t0 = time()
    pred = clf.predict(X_valid)
    test_time = time() - t0
    print(f"inference time:  {test_time:.3}s")

    balanced_accuracy = balanced_accuracy_score(y_valid, pred)
    print(f"Balanced accuracy score:    {balanced_accuracy:.3}")

    macro_f1 = f1_score(y_valid, pred, average="macro")
    print(f"Macro F1 score:    {macro_f1:.3}")

    weighted_f1 = f1_score(y_valid, pred, average="weighted")
    print(f"Weighted F1 score:    {weighted_f1:.3}")

    if hasattr(clf, "coef_"):
        print(f"dimensionality: {clf.coef_.shape[1]}")
        print(f"density: {density(clf.coef_)}")
        print()
    
    print()
    if custom_name:
        clf_descr = str(custom_name)
    else:
        clf_descr = clf.__class__.__name__
    return clf_descr, balanced_accuracy, macro_f1, weighted_f1, train_time, test_time

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

results = []
for clf, name in (
    (LogisticRegression(class_weight="balanced"), "Logistic Regression"),
    (RidgeClassifier(class_weight="balanced"), "Ridge Classifier"),
    (KNeighborsClassifier(), "kNN"),
    (RandomForestClassifier(class_weight="balanced"), "RandomForest Classifier"),
    (LinearSVC(class_weight="balanced"), "Linear SVC"),
    (SGDClassifier(class_weight="balanced"), "SGD Classifier"),
    (NearestCentroid(), "NearestCentroid"),
):
    print("=" * 80)
    print(name)
    results.append(benchmark(clf, name))
# Out:
# ================================================================================
# Logistic Regression
# ________________________________________________________________________________
# Training:
# LogisticRegression(class_weight='balanced')
# train time: 20.4s
# inference time:  0.0159s
# Balanced accuracy score:    0.782
# Macro F1 score:    0.694
# Weighted F1 score:    0.824
# dimensionality: 29947
# density: 1.0
#
#
# ================================================================================
# Ridge Classifier
# ________________________________________________________________________________
# Training:
# RidgeClassifier(class_weight='balanced')
# train time: 12.0s
# inference time:  0.00361s
# Balanced accuracy score:    0.763
# Macro F1 score:    0.667
# Weighted F1 score:    0.812
# dimensionality: 29947
# density: 1.0
#
#
# ================================================================================
# kNN
# ________________________________________________________________________________
# Training:
# KNeighborsClassifier()
# train time: 0.0144s
# inference time:  6.4s
# Balanced accuracy score:    0.591
# Macro F1 score:    0.616
# Weighted F1 score:    0.821
#
# ================================================================================
# RandomForest Classifier
# ________________________________________________________________________________
# Training:
# RandomForestClassifier(class_weight='balanced')
# train time: 2.77e+02s
# inference time:  0.167s
# Balanced accuracy score:    0.412
# Macro F1 score:    0.427
# Weighted F1 score:    0.724
#
# ================================================================================
# Linear SVC
# ________________________________________________________________________________
# Training:
# LinearSVC(class_weight='balanced')
# train time: 14.2s
# inference time:  0.00258s
# Balanced accuracy score:    0.726
# Macro F1 score:    0.7
# Weighted F1 score:    0.841
# dimensionality: 29947
# density: 1.0
#
#
# ================================================================================
# SGD Classifier
# ________________________________________________________________________________
# Training:
# SGDClassifier(class_weight='balanced')
# train time: 2.47s
# inference time:  0.00311s
# Balanced accuracy score:    0.779
# Macro F1 score:    0.67
# Weighted F1 score:    0.827
# dimensionality: 29947
# density: 0.6467070992086018
#
#
# ================================================================================
# NearestCentroid
# ________________________________________________________________________________
# Training:
# NearestCentroid()
# train time: 26.0s
# inference time:  0.0302s
# Balanced accuracy score:    0.709
# Macro F1 score:    0.598
# Weighted F1 score:    0.757

# %%
import numpy as np
import matplotlib.pyplot as plt  # Make sure matplotlib is imported

indices = np.arange(len(results))

# Extract all 6 elements from the results
results = [[x[i] for x in results] for i in range(6)]

# Unpack all 6 elements
clf_names, balanced_accuracy_scores, macro_f1_scores, weighted_f1_scores, training_time, test_time = results
training_time = np.array(training_time)
test_time = np.array(test_time)

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.scatter(macro_f1_scores, training_time, s=60)
ax1.set(
    title="Macro F1 scores-training time trade-off",
    yscale="log",
    xlabel="Test Macro F1 score",
    ylabel="training time (s)",
)

fig, ax2 = plt.subplots(figsize=(10, 8))
ax2.scatter(macro_f1_scores, test_time, s=60)
ax2.set(
    title="Macro F1 scores-test time trade-off",
    yscale="log",
    xlabel="Test Macro F1 score",
    ylabel="test time (s)",
)


# Add text annotations to all plots
for i, txt in enumerate(clf_names):
    ax1.annotate(txt, (macro_f1_scores[i], training_time[i]))
    ax2.annotate(txt, (macro_f1_scores[i], test_time[i]))

# %%
from src.utils import plot_confusion_matrix
from sklearn.svm import LinearSVC

svm_clf = LinearSVC(class_weight="balanced", random_state=42)
svm_clf.fit(X_train, y_train)
y_preds = svm_clf.predict(X_valid)

plot_confusion_matrix(y_preds, y_valid, labels)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_valid, y_preds, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#     astro-ph       0.95      0.89      0.92       120
#     cond-mat       0.84      0.76      0.80       137
#           cs       0.93      0.89      0.91       818
#         econ       0.82      0.64      0.72        14
#         eess       0.48      0.60      0.53        84
#        gr-qc       0.71      0.78      0.75        32
#          hep       0.85      0.90      0.87        79
#         math       0.89      0.89      0.89       331
#      math-ph       0.29      0.25      0.27         8
#         nlin       0.62      0.62      0.62         8
#         nucl       0.87      0.72      0.79        18
#      physics       0.68      0.65      0.67       123
#        q-bio       0.42      0.73      0.54        15
#        q-fin       0.38      0.71      0.50         7
#     quant-ph       0.80      0.91      0.85        90
#         stat       0.51      0.66      0.57        41
#
#     accuracy                           0.84      1925
#    macro avg       0.69      0.73      0.70      1925
# weighted avg       0.85      0.84      0.84      1925
