# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datasets import DatasetDict, Dataset
from transformers import pipeline
from tqdm import tqdm
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import glob
from sklearn.model_selection import train_test_split

# %%
# Define the path to the interim data directory
data_path = "data/interim/part-*.json"
json_files = glob.glob(data_path)
papers_df = pd.concat([pd.read_json(file, lines=True) for file in json_files], ignore_index=True)

# papers_df["arxiv_main_category"] = papers_df["main_category"].apply(map_category)
papers_df["text"] = papers_df["title"] + "\n" + papers_df["summary"]
papers_df = papers_df[["text", "main_category"]]

# %%
# Filter out rare categories
category_counts = papers_df['main_category'].value_counts()
min_examples = 10
candidate_categories = category_counts[category_counts >= min_examples].index.tolist()

# Filter the DataFrame to only include these categories
papers_df = papers_df[papers_df['main_category'].isin(candidate_categories)]

# %%
# First split: 80% training, 20% temp (test + validation)
train_df, temp_df = train_test_split(
    papers_df, 
    test_size=0.2,
    stratify=papers_df["main_category"],
    random_state=42
)

# Second split: Split temp into validation (50%) and test (50%)
# This gives us the final 10% validation, 10% test split from original dataset
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    stratify=temp_df["main_category"],
    random_state=42
)

# %%
# Print split sizes to verify
print(f"Training set: {len(train_df)} examples ({len(train_df)/len(papers_df)*100:.1f}%)")
print(f"Validation set: {len(val_df)} examples ({len(val_df)/len(papers_df)*100:.1f}%)")
print(f"Test set: {len(test_df)} examples ({len(test_df)/len(papers_df)*100:.1f}%)")

# Check category distribution across all splits using pandas
print(f"Total categories to classify: {len(papers_df['main_category'].unique())}")

# Dictionary of DataFrames for easy iteration
split_dfs = {
    "train": train_df,
    "validation": val_df,
    "test": test_df
}

for split_name, df in split_dfs.items():
    # Get unique categories in this split
    split_categories = set(df["main_category"].unique())
    
    # Check if all categories are present
    missing_categories = set(papers_df["main_category"]) - split_categories
    
    print(f"\nSplit: {split_name}")
    print(f"Number of unique categories: {len(split_categories)}")
    print(f"Categories present: {len(split_categories)}/{len(papers_df['main_category'].unique())}")
# Out:
# Training set: 5310 examples (80.0%)
# Validation set: 664 examples (10.0%)
# Test set: 664 examples (10.0%)
# Total categories to classify: 103
#
# Split: train
# Number of unique categories: 103
# Categories present: 103/103
#
# Split: validation
# Number of unique categories: 103
# Categories present: 103/103
#
# Split: test
# Number of unique categories: 103
# Categories present: 103/103

# %%
# Create the final DatasetDict with train, validation, and test splits
data = DatasetDict({
    "train": Dataset.from_pandas(train_df, preserve_index=False),
    "validation": Dataset.from_pandas(val_df, preserve_index=False),
    "test": Dataset.from_pandas(test_df, preserve_index=False)
})

# Print the final split dataset structure
print(data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'main_category'],
#         num_rows: 5310
#     })
#     validation: Dataset({
#         features: ['text', 'main_category'],
#         num_rows: 664
#     })
#     test: Dataset({
#         features: ['text', 'main_category'],
#         num_rows: 664
#     })
# })

# %%
# Path to HF model
model_path = "oracat/bert-paper-classifier-arxiv"

# Load model into pipeline
cls = pipeline(
    "text-classification",
    model=model_path,
    tokenizer=model_path,
    return_all_scores=True,
    device=-1,
    truncation=True,
    max_length=512
)
# Out:
# Device set to use cpu
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\transformers\pipelines\text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
def top_pct(preds, threshold=.95):
    preds = sorted(preds, key=lambda x: -x["score"])
    
    cum_score = 0
    for i, item in enumerate(preds):
        cum_score += item["score"]
        if cum_score >= threshold:
            break

    preds = preds[:(i+1)]
    
    return preds


def format_predictions(preds) -> str:
    """
    Prepare predictions and their scores for printing to the user
    """
    out = ""
    for i, item in enumerate(preds):
        out += f"{i+1}. {item['label']} (score {item['score']:.2f})\n"
    return out

# %%
# Process all examples and collect predictions in one pass
results = [(example["main_category"], 
            cls(example["text"])[0], 
            top_pct(cls(example["text"])[0])) 
           for example in tqdm(data["test"], desc="Classifying")]

# Unpack results
true_labels, raw_preds, all_predictions = zip(*results)
predicted_labels = [p[0]["label"] for p in all_predictions]

# Calculate and display metrics
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Test: {len(true_labels)} examples, {len(set(true_labels))} classes, {len(set(predicted_labels))} predicted")
print(f"Accuracy: {accuracy:.4f} ({int(accuracy * len(true_labels))}/{len(true_labels)})")
print(f"\nClassification Report:\n{classification_report(true_labels, predicted_labels)}")

# Show sample predictions
print("\nSample Predictions (first 5):")
for i, (true, pred, top_preds) in enumerate(zip(true_labels[:5], predicted_labels[:5], all_predictions[:5])):
    print(f"\nEx {i+1}: True: {true} | Pred: {pred}")
    print(format_predictions(top_preds))
# Out:
# Classifying: 100%|██████████| 664/664 [03:39<00:00,  3.02it/s]
# Test: 664 examples, 103 classes, 59 predicted
# Accuracy: 0.3178 (211/664)
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#        astro-ph.CO       0.09      0.50      0.15         8
#        astro-ph.EP       0.00      0.00      0.00         6
#        astro-ph.GA       0.00      0.00      0.00         9
#        astro-ph.HE       0.00      0.00      0.00         8
#        astro-ph.IM       0.11      0.75      0.19         4
#        astro-ph.SR       0.00      0.00      0.00         7
#    cond-mat.dis-nn       0.00      0.00      0.00         2
#  cond-mat.mes-hall       0.00      0.00      0.00         9
#  cond-mat.mtrl-sci       0.00      0.00      0.00        14
# cond-mat.quant-gas       0.00      0.00      0.00         3
#      cond-mat.soft       0.00      0.00      0.00         7
# cond-mat.stat-mech       0.03      0.25      0.06         4
#    cond-mat.str-el       0.00      0.00      0.00         8
#  cond-mat.supr-con       0.00      0.00      0.00         4
#              cs.AI       0.14      0.60      0.23        15
#              cs.AR       0.00      0.00      0.00         4
#              cs.CC       0.00      0.00      0.00         1
#              cs.CE       0.00      0.00      0.00         3
#              cs.CG       0.00      0.00      0.00         1
#              cs.CL       0.59      0.75      0.66        36
#              cs.CR       0.50      0.40      0.44        10
#              cs.CV       0.64      0.89      0.74        82
#              cs.CY       0.00      0.00      0.00         3
#              cs.DB       1.00      0.67      0.80         3
#              cs.DC       0.50      0.25      0.33         4
#              cs.DL       0.00      0.00      0.00         0
#              cs.DM       0.00      0.00      0.00         0
#              cs.DS       0.25      0.50      0.33         4
#              cs.ET       0.00      0.00      0.00         0
#              cs.FL       0.00      0.00      0.00         1
#              cs.GR       0.00      0.00      0.00         4
#              cs.GT       0.50      0.50      0.50         2
#              cs.HC       0.33      0.11      0.17         9
#              cs.IR       1.00      0.38      0.55         8
#              cs.IT       0.07      0.14      0.09         7
#              cs.LG       0.36      0.41      0.38        44
#              cs.LO       1.00      0.50      0.67         2
#              cs.MA       0.00      0.00      0.00         1
#              cs.MM       0.00      0.00      0.00         2
#              cs.NA       0.00      0.00      0.00         0
#              cs.NE       0.12      1.00      0.22         1
#              cs.NI       0.44      1.00      0.62         4
#              cs.PL       0.00      0.00      0.00         2
#              cs.RO       0.82      0.50      0.62        18
#              cs.SD       1.00      0.25      0.40         4
#              cs.SE       0.50      0.33      0.40         9
#              cs.SI       0.20      0.50      0.29         2
#              cs.SY       0.00      0.00      0.00         0
#            econ.GN       0.00      0.00      0.00         3
#            econ.TH       0.00      0.00      0.00         1
#            eess.AS       0.00      0.00      0.00         1
#            eess.IV       0.00      0.00      0.00         5
#            eess.SP       0.00      0.00      0.00        11
#            eess.SY       0.00      0.00      0.00        12
#              gr-qc       0.00      0.00      0.00        12
#             hep-ex       0.00      0.00      0.00         4
#            hep-lat       0.00      0.00      0.00         2
#             hep-ph       0.00      0.00      0.00        14
#             hep-th       0.00      0.00      0.00        10
#            math-ph       0.00      0.00      0.00         2
#            math.AC       0.00      0.00      0.00         2
#            math.AG       0.00      0.00      0.00         6
#            math.AP       0.00      0.00      0.00        15
#            math.AT       0.00      0.00      0.00         1
#            math.CA       0.00      0.00      0.00         3
#            math.CO       0.00      0.00      0.00        10
#            math.CT       0.00      0.00      0.00         1
#            math.CV       0.00      0.00      0.00         2
#            math.DG       0.00      0.00      0.00         6
#            math.DS       0.00      0.00      0.00         6
#            math.FA       0.08      0.20      0.11         5
#            math.GR       0.00      0.00      0.00         4
#            math.GT       0.00      0.00      0.00         4
#            math.LO       0.00      0.00      0.00         1
#            math.MG       0.00      0.00      0.00         1
#            math.NA       0.00      0.00      0.00         9
#            math.NT       0.00      0.00      0.00         6
#            math.OA       0.00      0.00      0.00         1
#            math.OC       0.32      0.55      0.40        11
#            math.PR       0.00      0.00      0.00         8
#            math.QA       0.00      0.00      0.00         1
#            math.RA       0.00      0.00      0.00         2
#            math.RT       0.00      0.00      0.00         4
#            math.SP       0.00      0.00      0.00         1
#            math.ST       0.00      0.00      0.00         4
#            nlin.AO       0.00      0.00      0.00         0
#            nlin.CD       0.00      0.00      0.00         1
#            nucl-ex       0.00      0.00      0.00         2
#            nucl-th       0.00      0.00      0.00         4
#     physics.acc-ph       0.00      0.00      0.00         2
#      physics.ao-ph       0.50      0.50      0.50         2
#     physics.app-ph       0.00      0.00      0.00         2
#    physics.atom-ph       0.00      0.00      0.00         2
#    physics.chem-ph       0.00      0.00      0.00         2
#    physics.comp-ph       0.20      0.50      0.29         2
#    physics.data-an       0.00      0.00      0.00         0
#    physics.flu-dyn       0.00      0.00      0.00         7
#     physics.geo-ph       0.00      0.00      0.00         1
#    physics.ins-det       0.00      0.00      0.00         1
#     physics.med-ph       0.50      0.50      0.50         2
#     physics.optics       0.67      0.40      0.50        10
#   physics.plasm-ph       0.00      0.00      0.00         2
#     physics.soc-ph       0.00      0.00      0.00         4
#           q-bio.NC       0.33      0.50      0.40         2
#           q-bio.PE       0.50      0.50      0.50         2
#           q-bio.QM       0.00      0.00      0.00         0
#           q-fin.ST       0.00      0.00      0.00         0
#           quant-ph       0.67      0.71      0.69        31
#            stat.AP       0.00      0.00      0.00         2
#            stat.CO       0.00      0.00      0.00         1
#            stat.ME       1.00      0.14      0.25         7
#            stat.ML       0.07      0.67      0.13         3
#
#           accuracy                           0.32       664
#          macro avg       0.13      0.15      0.12       664
#       weighted avg       0.28      0.32      0.28       664
#
#
# Sample Predictions (first 5):
#
# Ex 1: True: math.CO | Pred: cs.IT
# 1. cs.IT (score 0.40)
# 2. math.FA (score 0.07)
# 3. cond-mat.stat-mech (score 0.05)
# 4. math.PR (score 0.03)
# 5. math.DS (score 0.02)
# 6. math.NA (score 0.02)
# 7. math.ST (score 0.02)
# 8. physics.data-an (score 0.01)
# 9. cs.DM (score 0.01)
# 10. math.DG (score 0.01)
# 11. cs.NA (score 0.01)
# 12. math.AG (score 0.01)
# 13. astro-ph.CO (score 0.01)
# 14. stat.CO (score 0.01)
# 15. math.CO (score 0.01)
# 16. physics.comp-ph (score 0.01)
# 17. cs.DS (score 0.01)
# 18. math.AT (score 0.01)
# 19. hep-lat (score 0.01)
# 20. math.RA (score 0.01)
# 21. math.GR (score 0.01)
# 22. nlin.CG (score 0.01)
# 23. math.GT (score 0.01)
# 24. hep-ex (score 0.01)
# 25. hep-ph (score 0.01)
# 26. physics.gen-ph (score 0.01)
# 27. physics.optics (score 0.01)
# 28. cs.CC (score 0.01)
# 29. cs.SC (score 0.01)
# 30. math.AP (score 0.01)
# 31. gr-qc (score 0.01)
# 32. cond-mat.soft (score 0.01)
# 33. astro-ph.IM (score 0.01)
# 34. cs.CG (score 0.01)
# 35. cs.FL (score 0.00)
# 36. math.HO (score 0.00)
# 37. astro-ph.GA (score 0.00)
# 38. physics.hist-ph (score 0.00)
# 39. quant-ph (score 0.00)
# 40. nlin.PS (score 0.00)
# 41. astro-ph.SR (score 0.00)
# 42. math.MG (score 0.00)
# 43. nlin.CD (score 0.00)
# 44. q-fin.EC (score 0.00)
# 45. math.GN (score 0.00)
# 46. astro-ph (score 0.00)
# 47. physics.class-ph (score 0.00)
# 48. hep-th (score 0.00)
# 49. stat.OT (score 0.00)
# 50. cond-mat.other (score 0.00)
# 51. physics.soc-ph (score 0.00)
# 52. math.GM (score 0.00)
# 53. math.CA (score 0.00)
# 54. math.RT (score 0.00)
# 55. physics.chem-ph (score 0.00)
# 56. q-bio.CB (score 0.00)
# 57. cond-mat.dis-nn (score 0.00)
# 58. cs.GR (score 0.00)
# 59. cs.MS (score 0.00)
# 60. physics.geo-ph (score 0.00)
# 61. math.CT (score 0.00)
# 62. q-fin.TR (score 0.00)
# 63. cond-mat.mtrl-sci (score 0.00)
# 64. math.LO (score 0.00)
# 65. q-fin.RM (score 0.00)
# 66. cs.GL (score 0.00)
# 67. eess.AS (score 0.00)
# 68. stat.ME (score 0.00)
# 69. q-fin.GN (score 0.00)
# 70. econ.EM (score 0.00)
# 71. cs.OS (score 0.00)
#
#
# Ex 2: True: math.GT | Pred: cs.CV
# 1. cs.CV (score 0.86)
# 2. cs.CL (score 0.09)
#
#
# Ex 3: True: cond-mat.mtrl-sci | Pred: cond-mat.stat-mech
# 1. cond-mat.stat-mech (score 0.12)
# 2. cond-mat.dis-nn (score 0.06)
# 3. physics.comp-ph (score 0.03)
# 4. cond-mat.mtrl-sci (score 0.03)
# 5. cs.ET (score 0.03)
# 6. astro-ph.CO (score 0.03)
# 7. nlin.CG (score 0.03)
# 8. cond-mat.soft (score 0.02)
# 9. quant-ph (score 0.02)
# 10. hep-ph (score 0.02)
# 11. hep-lat (score 0.02)
# 12. cond-mat.other (score 0.02)
# 13. physics.gen-ph (score 0.02)
# 14. astro-ph.SR (score 0.02)
# 15. astro-ph.GA (score 0.02)
# 16. q-bio.BM (score 0.02)
# 17. hep-ex (score 0.02)
# 18. nlin.CD (score 0.02)
# 19. gr-qc (score 0.01)
# 20. hep-th (score 0.01)
# 21. astro-ph (score 0.01)
# 22. physics.chem-ph (score 0.01)
# 23. physics.geo-ph (score 0.01)
# 24. physics.ao-ph (score 0.01)
# 25. math.GR (score 0.01)
# 26. math.DS (score 0.01)
# 27. physics.optics (score 0.01)
# 28. math.AG (score 0.01)
# 29. adap-org (score 0.01)
# 30. math.HO (score 0.01)
# 31. eess.SP (score 0.01)
# 32. physics.hist-ph (score 0.01)
# 33. physics.ins-det (score 0.01)
# 34. nlin.PS (score 0.01)
# 35. q-bio.CB (score 0.01)
# 36. math.RA (score 0.01)
# 37. math.RT (score 0.01)
# 38. q-bio.MN (score 0.01)
# 39. math.DG (score 0.01)
# 40. astro-ph.IM (score 0.01)
# 41. math.AT (score 0.01)
# 42. cs.PF (score 0.01)
# 43. q-fin.TR (score 0.01)
# 44. nlin.AO (score 0.01)
# 45. physics.class-ph (score 0.01)
# 46. q-bio.TO (score 0.01)
# 47. cond-mat (score 0.01)
# 48. math.AP (score 0.01)
# 49. q-fin.EC (score 0.01)
# 50. math.GM (score 0.01)
# 51. cs.OS (score 0.01)
# 52. math.CA (score 0.01)
# 53. math.MG (score 0.01)
# 54. math.GN (score 0.01)
# 55. math.NT (score 0.01)
# 56. nucl-th (score 0.01)
# 57. physics.bio-ph (score 0.01)
# 58. cond-mat.supr-con (score 0.01)
# 59. q-fin.CP (score 0.01)
# 60. math.GT (score 0.01)
# 61. physics.med-ph (score 0.00)
# 62. q-fin.ST (score 0.00)
# 63. cs.AR (score 0.00)
# 64. stat.OT (score 0.00)
# 65. q-bio.GN (score 0.00)
# 66. physics.data-an (score 0.00)
# 67. eess.IV (score 0.00)
# 68. q-fin.GN (score 0.00)
# 69. cs.GL (score 0.00)
# 70. econ.EM (score 0.00)
# 71. math.FA (score 0.00)
# 72. cs.SC (score 0.00)
# 73. q-bio.NC (score 0.00)
# 74. astro-ph.EP (score 0.00)
# 75. q-fin.RM (score 0.00)
# 76. cs.OH (score 0.00)
# 77. math.CT (score 0.00)
# 78. math.NA (score 0.00)
# 79. eess.AS (score 0.00)
#
#
# Ex 4: True: cs.CL | Pred: cs.CL
# 1. cs.CL (score 0.94)
# 2. cs.AI (score 0.02)
#
#
# Ex 5: True: cs.LG | Pred: q-bio.QM
# 1. q-bio.QM (score 0.28)
# 2. cs.LG (score 0.21)
# 3. stat.ML (score 0.12)
# 4. q-bio.BM (score 0.11)
# 5. q-bio.GN (score 0.06)
# 6. cs.CE (score 0.05)
# 7. stat.AP (score 0.02)
# 8. cs.CV (score 0.01)
# 9. math.OC (score 0.01)
# 10. math.ST (score 0.00)
# 11. q-bio.MN (score 0.00)
# 12. stat.CO (score 0.00)
# 13. physics.med-ph (score 0.00)
# 14. physics.data-an (score 0.00)
# 15. econ.EM (score 0.00)
# 16. cs.DC (score 0.00)
# 17. cs.NA (score 0.00)
# 18. cs.NE (score 0.00)
# 19. cs.MS (score 0.00)
# 20. q-bio.PE (score 0.00)
# 21. eess.IV (score 0.00)
# 22. stat.ME (score 0.00)
# 23. cond-mat.stat-mech (score 0.00)
# 24. eess.SP (score 0.00)
# 25. cs.IT (score 0.00)
# 26. astro-ph.IM (score 0.00)
# 27. math.NA (score 0.00)
# 28. physics.ao-ph (score 0.00)
# 29. physics.soc-ph (score 0.00)
# 30. physics.comp-ph (score 0.00)
# 31. cs.DS (score 0.00)
# 32. cs.IR (score 0.00)
# 33. q-fin.ST (score 0.00)
# 34. physics.geo-ph (score 0.00)
# 35. cs.AI (score 0.00)
# 36. cond-mat.dis-nn (score 0.00)
# 37. cs.SY (score 0.00)
# 38. cs.MA (score 0.00)
# 39. cs.SE (score 0.00)
# 40. eess.AS (score 0.00)
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\GPham\miniforge3\envs\assignment-03\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
